# %%
import pandas as pd

# %%
print("hello")
# Out:
# hello

# %%
df=pd.read_csv(r"C:/Users/benij/ds_project/Ai_pettition_project/backend/data/petition_dataset.csv")

# %%
df['label'].unique()
# Out:
# array([' Urgent Action Required', ' Normal Action', ' Fast Action'],
#       dtype=object)

# %%
df['paragraph'].max()
# Out:
# 'We would like the city to install a historical plaque at the site of the first bakery in town. It is a small piece of history that would be nice for people to read while they walk their dogs. There is no rush, but it would be a nice addition to the downtown walking tour project.'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   paragraph  135 non-null    object
#  1   label      135 non-null    object
# dtypes: object(2)
# memory usage: 2.2+ KB

# %%
df['paragraph'].str.lower().head(2)
# Out:
# 0    the residents of the eastside district have be...
# 1    the local historical society is calling for a ...
# Name: paragraph, dtype: object

# %%
df['label'].value_counts()
# Out:
# label
#  Urgent Action Required    50
#  Normal Action             44
#  Fast Action               41
# Name: count, dtype: int64

# %%
df['paragraph'].to_list()
# Out:
# ['The residents of the Eastside District have been without clean running water for 72 hours following the chemical spill at the nearby processing plant. We are seeing cases of skin rashes and gastrointestinal illness in children. We demand the immediate deployment of water tankers and the distribution of filtration kits before this becomes a full-scale public health catastrophe. The city must act within the next 6 hours to prevent further injury.',
#  'The local historical society is calling for a long-term study to be conducted regarding the architectural significance of the old clock tower on 5th Avenue. We believe that by 2027 the city should consider allocating a small grant to restore the masonry and potentially turn the ground floor into a small museum for local artifacts. This would be a wonderful way to preserve our heritage for future generations.',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
plt.title("label distribution")
sns.countplot(data=df,x='label',color='green')
plt.Annotation
plt.savefig("C:/Users/benij/ds_project/Ai_pettition_project/backend/notebooks/charts/data_distibution_chart.png")

# %%
type(df),type("gr")
# Out:
# (pandas.core.frame.DataFrame, str)
